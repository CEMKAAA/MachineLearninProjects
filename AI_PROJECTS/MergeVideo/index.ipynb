# %%
from moviepy.editor import VideoFileClip, concatenate_videoclips 

def merge_videos(video1_path, video2_path, output_path):
    # Load the video clips
    video1 = VideoFileClip(video1_path)
    video2 = VideoFileClip(video2_path)

    # Concatenate the video clips
    final_clip = concatenate_videoclips([video1, video2])

    # Write the final merged video to a file
    final_clip.write_videofile(output_path, codec="libx264")

    # Close the video files
    video1.close()
    video2.close()

# Paths to the input videos
video1_path = "C:/Users/Cem/Documents/Bandicam/video1.mp4"
video2_path = "C:/Users/Cem/Documents/Bandicam/video2.mp4"

# Path to the output merged video
output_path = "odevvideo.mp4"

# Merge the videos
merge_videos(video1_path, video2_path, output_path)
# Out:
#
#
#
# t:   0%|          | 2/31389 [16:57<4434:00:34, 508.57s/it, now=None]
#
#
#
# t:   0%|          | 2/31389 [16:57<4434:04:53, 508.58s/it, now=None]
# Moviepy - Building video odevvideo.mp4.
# MoviePy - Writing audio in odevvideoTEMP_MPY_wvf_snd.mp3
#
#
#
# t:   0%|          | 2/31389 [17:09<4486:47:33, 514.62s/it, now=None]
#
#
#
# t:   0%|          | 2/31389 [17:09<4486:50:30, 514.63s/it, now=None]
# MoviePy - Done.
# Moviepy - Writing video odevvideo.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 26
#      23 output_path = "odevvideo.mp4"
#      25 # Merge the videos
# ---> 26 merge_videos(video1_path, video2_path, output_path)
#
# Cell In[5], line 12, in merge_videos(video1_path, video2_path, output_path)
#       9 final_clip = concatenate_videoclips([video1, video2])
#      11 # Write the final merged video to a file
# ...
